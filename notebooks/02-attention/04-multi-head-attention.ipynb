# %% [markdown]
# # 04 - Multi-Head Attention
#
# **Status:** planned after causal attention.
#
# Run several causal-attention heads in parallel, concatenate their outputs, and implement the efficient combined projection used by GPT-style models.
